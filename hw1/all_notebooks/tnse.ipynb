# %%
import pyLDAvis
from collections import Counter
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import gensim
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter, defaultdict
# %matplotlib inline
from sklearn.model_selection import train_test_split

import sys
# Out:
# /home/autodeploy/.local/lib/python3.5/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.feature_extraction.text import *
import pickle

with open('/mnt/dump/dump_pipeline/M_word2vec_our_vect_train.pickle', 'rb') as f:
    M_word2vec_our_vect_train = pickle.load(f)

with open('/mnt/dump/dump_pipeline/M_word2vec_our_vect_test.pickle', 'rb') as f:
    M_word2vec_our_vect_test = pickle.load(f)
vectors = M_word2vec_our_vect_train
X_reduced = TruncatedSVD(n_components=100, random_state=0).fit_transform(vectors)
X_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_reduced)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 85219 samples in 0.367s...
# [t-SNE] Computed neighbors for 85219 samples in 529.440s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 85219
# [t-SNE] Computed conditional probabilities for sample 2000 / 85219
# [t-SNE] Computed conditional probabilities for sample 3000 / 85219
# [t-SNE] Computed conditional probabilities for sample 4000 / 85219
# [t-SNE] Computed conditional probabilities for sample 5000 / 85219
# [t-SNE] Computed conditional probabilities for sample 6000 / 85219
# [t-SNE] Computed conditional probabilities for sample 7000 / 85219
# [t-SNE] Computed conditional probabilities for sample 8000 / 85219
# [t-SNE] Computed conditional probabilities for sample 9000 / 85219
# [t-SNE] Computed conditional probabilities for sample 10000 / 85219
# [t-SNE] Computed conditional probabilities for sample 11000 / 85219
# [t-SNE] Computed conditional probabilities for sample 12000 / 85219
# ...

# %%
sns.FacetGrid(df, hue="topic", size=10).map(plt.scatter, "X", "Y")
# Out:
# /home/autodeploy/.local/lib/python3.5/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Здесь мы можем видеть визуализацию векторов, полученных с помощью wor2vec.
