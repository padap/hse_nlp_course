# %%
from collections import Counter
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('eurlex_data.txt',header=None).rename(columns={0:"label",1:"text"})

# %%
df
# Out:
#        label                                               text
# 0         14   "convent intern commiss rhine bern convent le...
# 1         17   "exchang letter commiss intern bureau weight ...
# 2         38   "council decis juli conclus protocol access u...
# 3         41   "addit agreement agreement product clock watc...
# 4         42   "exchang letter india excel mr swaminathan am...
# 5         43   "exchang letter pakistan excel mr riaz pirach...
# 6         45   "addit protocol preambl majesti king belgian ...
# 7         46   "agreement product provinc european coal stee...
# 8         52   "agreement european econom commun swiss confe...
# 9         53   "council direct decemb tax turnov tax affect ...
# 10        55   "regul eec council decemb conclus protocol fi...
# 11        56   "protocol lai provis relat agreement european...
# 12        57   "agreement establish associ european econom c...
# 13        58   "protocol lai provis relat agreement establis...
# 14        60   "annex convent intern trade endang speci wild...
# 15        62   "agreement member state european coal steel c...
# 16        63   "annex intern convent simplif harmon custom p...
# 17        64   "supplementari protocol associ agreement euro...
# 18        65   "supplementari protocol product provinc europ...
# 19        66   "agreement member state european coal steel c...
# 20        67   "agreement member state european coal steel c...
# 21        68   "addit agreement valid princip liechtenstein ...
# 22        69   "protocol relat agreement trade technic coope...
# 23        70   "interim agreement european econom commun tur...
# 24        71   "protocol lai provis relat agreement european...
# 25        72   "exchang letter amend articl annex addit prot...
# 26        73   "annex excel draw attent error form articl pr...
# 27        74   "european agreement exchang tissu type reagen...
# 28        76   "supplementari protocol agreement european ec...
# 29        77   "supplementari protocol agreement european ec...
# ...      ...                                                ...
# 19318  19906   "resolut council repres govern member state m...
# 19319  19909   "decis common accord govern member state adop...
# 19320  19910   "decis repres govern member state juli appoin...
# 19321  19911   "perman repres committe decis septemb set ad ...
# 19322  19912   "decis common accord level head state govern ...
# 19323  19913   "joint declar council repres govern member st...
# 19324  19915   "agreement member state european union claim ...
# 19325  19916   "decis common agreement repres member state m...
# 19326  19917   "decis common accord level head state govern ...
# 19327  19918   "decis repres govern member state european un...
# 19328  19919   "decis repres govern member state european un...
# 19329  19920   "decis repres govern member state european un...
# 19330  19921   "decis repres govern member state meet counci...
# 19331  19922   "decis repres govern member state european un...
# 19332  19923   "decis repres govern member state septemb app...
# 19333  19924   "agreement conclud european transport worker ...
# 19334  19925   "convent law applic contractu oblig consolid ...
# 19335  19926   "decis repres govern member state meet counci...
# 19336  19927   "decis common accord level head state govern ...
# 19337  19928   "decis repres govern member state meet counci...
# 19338  19929   "decis repres govern member state juli appoin...
# 19339  19930   "decis repres govern member state octob appoi...
# 19340  19931   "resolut council repres govern member state m...
# 19341  19934   "resolut council repres govern member state m...
# 19342  19935   "conclus council repres govern member state m...
# 19343  19936   "decis repres govern member state april appoi...
# 19344  19937   "decis repres govern member state april appoi...
# 19345  19938   "decis repres govern member state april appoi...
# 19346  19939   "decis repres govern member state april appoi...
# 19347  19940   "administr agreement european commiss kingdom...
#
# [19348 rows x 2 columns]

# %%
y = pd.read_csv('eurlex_labels.txt',header=None,sep='\s').rename(index =str,columns={0:"title",1:'label'})
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
y
# Out:
#                                     title  label  2
# 0                environmental_protection     14  1
# 1              pollution_control_measures     14  1
# 2               environmental_cooperation     14  1
# 3                            rhine_valley     14  1
# 4                            ec_agreement     14  1
# 5                    european_cooperation     17  1
# 6                    weights_and_measures     17  1
# 7                   technical_cooperation     17  1
# 8                  scientific_cooperation     17  1
# 9                                    gatt     38  1
# 10                      tariff_preference     38  1
# 11               protocol_to_an_agreement     38  1
# 12                                  egypt     38  1
# 13                         customs_duties     38  1
# 14                           ec_agreement     41  1
# 15                            switzerland     41  1
# 16               clock_and_watch_industry     41  1
# 17                  technical_regulations     41  1
# 18                                  india     42  1
# 19                               pakistan     42  1
# 20                international_agreement     42  1
# 21                       craft_production     42  1
# 22                      trading_operation     42  1
# 23                           ec_agreement     43  1
# 24                               pakistan     43  1
# 25                        trade_agreement     43  1
# 26                           tariff_quota     43  1
# 27                       craft_production     43  1
# 28                                 turkey     45  1
# 29               protocol_to_an_agreement     45  1
# ...                                   ...    ... ..
# 102711                   education_policy  19934  1
# 102712                   higher_education  19934  1
# 102713                         university  19934  1
# 102714         educational_administration  19934  1
# 102715                             7951.0  19934  1
# 102716                             7951.0  19935  1
# 102717     continuing_vocational_training  19935  1
# 102718                   education_policy  19935  1
# 102719                  distance_learning  19935  1
# 102720                programmed_learning  19935  1
# 102721             information_technology  19935  1
# 102722        professional_qualifications  19935  1
# 102723                ec_court_of_justice  19936  1
# 102724               appointment_of_staff  19936  1
# 102725  member_of_the_ec_court_of_justice  19936  1
# 102726                ec_court_of_justice  19937  1
# 102727               appointment_of_staff  19937  1
# 102728  member_of_the_ec_court_of_justice  19937  1
# 102729         ec_court_of_first_instance  19938  1
# 102730               appointment_of_staff  19938  1
# 102731  member_of_the_ec_court_of_justice  19938  1
# 102732                ec_court_of_justice  19939  1
# 102733               appointment_of_staff  19939  1
# 102734  member_of_the_ec_court_of_justice  19939  1
# 102735         administrative_cooperation  19940  1
# 102736                      ec_commission  19940  1
# 102737                              spain  19940  1
# 102738               information_transfer  19940  1
# 102739                   use_of_languages  19940  1
# 102740                  official_language  19940  1
#
# [102741 rows x 3 columns]

# %%
t = df.merge(y,on ='label',how='inner')

# %%
t
# Out:
#         label                                               text  \
# 0          14   "convent intern commiss rhine bern convent le...
# 1          14   "convent intern commiss rhine bern convent le...
# 2          14   "convent intern commiss rhine bern convent le...
# 3          14   "convent intern commiss rhine bern convent le...
# 4          14   "convent intern commiss rhine bern convent le...
# 5          17   "exchang letter commiss intern bureau weight ...
# 6          17   "exchang letter commiss intern bureau weight ...
# 7          17   "exchang letter commiss intern bureau weight ...
# 8          17   "exchang letter commiss intern bureau weight ...
# 9          38   "council decis juli conclus protocol access u...
# 10         38   "council decis juli conclus protocol access u...
# 11         38   "council decis juli conclus protocol access u...
# 12         38   "council decis juli conclus protocol access u...
# 13         38   "council decis juli conclus protocol access u...
# 14         41   "addit agreement agreement product clock watc...
# 15         41   "addit agreement agreement product clock watc...
# 16         41   "addit agreement agreement product clock watc...
# 17         41   "addit agreement agreement product clock watc...
# 18         42   "exchang letter india excel mr swaminathan am...
# 19         42   "exchang letter india excel mr swaminathan am...
# 20         42   "exchang letter india excel mr swaminathan am...
# 21         42   "exchang letter india excel mr swaminathan am...
# 22         42   "exchang letter india excel mr swaminathan am...
# 23         43   "exchang letter pakistan excel mr riaz pirach...
# 24         43   "exchang letter pakistan excel mr riaz pirach...
# 25         43   "exchang letter pakistan excel mr riaz pirach...
# 26         43   "exchang letter pakistan excel mr riaz pirach...
# 27         43   "exchang letter pakistan excel mr riaz pirach...
# 28         45   "addit protocol preambl majesti king belgian ...
# 29         45   "addit protocol preambl majesti king belgian ...
# ...       ...                                                ...
# 102711  19934   "resolut council repres govern member state m...
# 102712  19934   "resolut council repres govern member state m...
# 102713  19934   "resolut council repres govern member state m...
# 102714  19934   "resolut council repres govern member state m...
# 102715  19934   "resolut council repres govern member state m...
# 102716  19935   "conclus council repres govern member state m...
# 102717  19935   "conclus council repres govern member state m...
# 102718  19935   "conclus council repres govern member state m...
# 102719  19935   "conclus council repres govern member state m...
# 102720  19935   "conclus council repres govern member state m...
# 102721  19935   "conclus council repres govern member state m...
# 102722  19935   "conclus council repres govern member state m...
# 102723  19936   "decis repres govern member state april appoi...
# 102724  19936   "decis repres govern member state april appoi...
# 102725  19936   "decis repres govern member state april appoi...
# 102726  19937   "decis repres govern member state april appoi...
# 102727  19937   "decis repres govern member state april appoi...
# 102728  19937   "decis repres govern member state april appoi...
# 102729  19938   "decis repres govern member state april appoi...
# 102730  19938   "decis repres govern member state april appoi...
# 102731  19938   "decis repres govern member state april appoi...
# 102732  19939   "decis repres govern member state april appoi...
# 102733  19939   "decis repres govern member state april appoi...
# 102734  19939   "decis repres govern member state april appoi...
# 102735  19940   "administr agreement european commiss kingdom...
# 102736  19940   "administr agreement european commiss kingdom...
# 102737  19940   "administr agreement european commiss kingdom...
# 102738  19940   "administr agreement european commiss kingdom...
# 102739  19940   "administr agreement european commiss kingdom...
# 102740  19940   "administr agreement european commiss kingdom...
#
#                                     title  2
# 0                environmental_protection  1
# 1              pollution_control_measures  1
# 2               environmental_cooperation  1
# 3                            rhine_valley  1
# 4                            ec_agreement  1
# 5                    european_cooperation  1
# 6                    weights_and_measures  1
# 7                   technical_cooperation  1
# 8                  scientific_cooperation  1
# 9                                    gatt  1
# 10                      tariff_preference  1
# 11               protocol_to_an_agreement  1
# 12                                  egypt  1
# 13                         customs_duties  1
# 14                           ec_agreement  1
# 15                            switzerland  1
# 16               clock_and_watch_industry  1
# 17                  technical_regulations  1
# 18                                  india  1
# 19                               pakistan  1
# 20                international_agreement  1
# 21                       craft_production  1
# 22                      trading_operation  1
# 23                           ec_agreement  1
# 24                               pakistan  1
# 25                        trade_agreement  1
# 26                           tariff_quota  1
# 27                       craft_production  1
# 28                                 turkey  1
# 29               protocol_to_an_agreement  1
# ...                                   ... ..
# 102711                   education_policy  1
# 102712                   higher_education  1
# 102713                         university  1
# 102714         educational_administration  1
# 102715                             7951.0  1
# 102716                             7951.0  1
# 102717     continuing_vocational_training  1
# 102718                   education_policy  1
# 102719                  distance_learning  1
# 102720                programmed_learning  1
# 102721             information_technology  1
# 102722        professional_qualifications  1
# 102723                ec_court_of_justice  1
# 102724               appointment_of_staff  1
# 102725  member_of_the_ec_court_of_justice  1
# 102726                ec_court_of_justice  1
# 102727               appointment_of_staff  1
# 102728  member_of_the_ec_court_of_justice  1
# 102729         ec_court_of_first_instance  1
# 102730               appointment_of_staff  1
# 102731  member_of_the_ec_court_of_justice  1
# 102732                ec_court_of_justice  1
# 102733               appointment_of_staff  1
# 102734  member_of_the_ec_court_of_justice  1
# 102735         administrative_cooperation  1
# 102736                      ec_commission  1
# 102737                              spain  1
# 102738               information_transfer  1
# 102739                   use_of_languages  1
# 102740                  official_language  1
#
# [102741 rows x 4 columns]

# %%
from collections import Counter
from matplotlib import pyplot as plt
# %matplotlib inline

N = 40

plt.figure(figsize = (10, 15))
plt.title('Количество классов', fontsize = 18)
plt.xlabel('N')
plt.ylabel('Класс')
count = list(sorted(Counter(t['title']).items(), key = lambda x: x[1]))[-N:]

lst_x = list([i[0] for i in count])
lst_y = list([i[1] for i in count])

plt.barh(range(len(lst_y)), lst_y)
plt.yticks(range(N), lst_x)

plt.show()

# %%
from collections import Counter
from matplotlib import pyplot as plt
# %matplotlib inline

N = 40

plt.figure(figsize = (20, 8))
plt.title('Количество классов', fontsize = 18)
plt.hist(list(Counter(t['title']).values()), bins = 100)
plt.ylabel('Number of samples')
plt.xlabel('Number of classes')
# lst_x = list([i[0] for i in count])
# lst_y = list([i[1] for i in count])

# plt.barh(range(len(lst_y)), lst_y)
# plt.yticks(range(N), lst_x)

plt.show()

# %%
plt.figure(figsize = (20, 8))
plt.title('Количество классов', fontsize = 18)
plt.hist(np.array(list(Counter(t['title']).values())), bins = 100)
plt.ylabel('Number of samples')
plt.xlabel('Number of classes')
plt.yscale('log', nonposy='clip')
plt.show()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(t['title'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['2164', '2164.0', '3485.0', ..., 'zoology', 'zoonosis',
#        'zootechnics'], dtype=object)

# %%
symbol_counter = Counter("".join(t['text']))

# %%
plt.figure(figsize = (20, 8))
plt.title('Уникальных символов', fontsize = 18)
plt.hist(symbol_counter.values(), bins = 100)
plt.ylabel('Количество символов')
plt.xlabel('Сколько раз встретились')
# plt.xscale('log', nonposy='clip')
plt.show()

# %%
symbol_counter['e']
# Out:
# 78755107

# %%
from collections import Counter
from matplotlib import pyplot as plt
# %matplotlib inline

N = 25

plt.figure(figsize = (10, 15))
plt.title('Количество уникальных символов', fontsize = 18)
plt.xlabel('Log10 P')
plt.ylabel('Символ')
norm = sum(symbol_counter.values())
count = list(sorted(symbol_counter.items(), key = lambda x: x[1]))[-N:]

lst_x = list([i[0] for i in count])
lst_y = np.log10(list([i[1]/norm for i in count]))

plt.barh(range(len(lst_y)), lst_y)
plt.yticks(range(N), lst_x)

plt.show()

# %%
from collections import Counter
from matplotlib import pyplot as plt
# %matplotlib inline

N = 25

plt.figure(figsize = (10, 15))
plt.title('Количество уникальных символов', fontsize = 18)
plt.xlabel('Log10 P')
plt.ylabel('Символ')
norm = sum(symbol_counter.values())
count = list(sorted(symbol_counter.items(), key = lambda x: x[1]))[:N]

lst_x = list([i[0] for i in count])
lst_y = np.log10(list([i[1]/norm for i in count]))

plt.barh(range(len(lst_y)), lst_y)
plt.yticks(range(N), lst_x)

plt.show()

# %% [markdown]
# Определим язык для предобработки текста

# %%
# !pip --version
# Out:
# pip 18.0 from /Library/Python/2.7/site-packages/pip (python 2.7)

# %%
import langdetect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-7a3189672429> in <module>()
# ----> 1 import langdetect
#
# ModuleNotFoundError: No module named 'langdetect'

# %%
t['target'] = le.transform(t['title'])

# %%
def remove_brackets (s):
    return s.replace("\"","")

# %%
t['features'] = t.text.apply(remove_brackets)

# %%
df = t.drop('text',axis = 1)[['features','target']]

# %%
df
# Out:
#                                                  features  target
# 0        convent intern commiss rhine bern convent le ...    1278
# 1        convent intern commiss rhine bern convent le ...    2806
# 2        convent intern commiss rhine bern convent le ...    1271
# 3        convent intern commiss rhine bern convent le ...    3157
# 4        convent intern commiss rhine bern convent le ...    1072
# 5        exchang letter commiss intern bureau weight m...    1342
# 6        exchang letter commiss intern bureau weight m...    3883
# 7        exchang letter commiss intern bureau weight m...    3567
# 8        exchang letter commiss intern bureau weight m...    3232
# 9        council decis juli conclus protocol access un...    1688
# 10       council decis juli conclus protocol access un...    3532
# 11       council decis juli conclus protocol access un...    2957
# 12       council decis juli conclus protocol access un...    1201
# 13       council decis juli conclus protocol access un...     873
# 14       addit agreement agreement product clock watch...    1072
# 15       addit agreement agreement product clock watch...    3512
# 16       addit agreement agreement product clock watch...     586
# 17       addit agreement agreement product clock watch...    3569
# 18       exchang letter india excel mr swaminathan amb...    1879
# 19       exchang letter india excel mr swaminathan amb...    2667
# 20       exchang letter india excel mr swaminathan amb...    1982
# 21       exchang letter india excel mr swaminathan amb...     822
# 22       exchang letter india excel mr swaminathan amb...    3668
# 23       exchang letter pakistan excel mr riaz piracha...    1072
# 24       exchang letter pakistan excel mr riaz piracha...    2667
# 25       exchang letter pakistan excel mr riaz piracha...    3647
# 26       exchang letter pakistan excel mr riaz piracha...    3533
# 27       exchang letter pakistan excel mr riaz piracha...     822
# 28       addit protocol preambl majesti king belgian p...    3732
# 29       addit protocol preambl majesti king belgian p...    2957
# ...                                                   ...     ...
# 102711   resolut council repres govern member state me...    1185
# 102712   resolut council repres govern member state me...    1795
# 102713   resolut council repres govern member state me...    3767
# 102714   resolut council repres govern member state me...    1187
# 102715   resolut council repres govern member state me...      15
# 102716   conclus council repres govern member state me...      15
# 102717   conclus council repres govern member state me...     773
# 102718   conclus council repres govern member state me...    1185
# 102719   conclus council repres govern member state me...     988
# 102720   conclus council repres govern member state me...    2930
# 102721   conclus council repres govern member state me...    1928
# 102722   conclus council repres govern member state me...    2926
# 102723   decis repres govern member state april appoin...    1087
# 102724   decis repres govern member state april appoin...     229
# 102725   decis repres govern member state april appoin...    2328
# 102726   decis repres govern member state april appoin...    1087
# 102727   decis repres govern member state april appoin...     229
# 102728   decis repres govern member state april appoin...    2328
# 102729   decis repres govern member state april appoin...    1086
# 102730   decis repres govern member state april appoin...     229
# 102731   decis repres govern member state april appoin...    2328
# 102732   decis repres govern member state april appoin...    1087
# 102733   decis repres govern member state april appoin...     229
# 102734   decis repres govern member state april appoin...    2328
# 102735   administr agreement european commiss kingdom ...      60
# 102736   administr agreement european commiss kingdom ...    1080
# 102737   administr agreement european commiss kingdom ...    3392
# 102738   administr agreement european commiss kingdom ...    1932
# 102739   administr agreement european commiss kingdom ...    3781
# 102740   administr agreement european commiss kingdom ...    2591
#
# [102741 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['features'], df['target'], test_size=0.1, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features = 1000)
X_train_new = vectorizer.fit_transform(X_train)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
X_train_new.shape
# Out:
# (92466, 1000)

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

clf = OneVsRestClassifier(LinearSVC(random_state=0))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
model = LogisticRegression()
model.fit(X_train_new, y_train)

X_test_new - vectorizer.transform(X_test)
p_test_new = model.predict_proba(X_test_new)

# %%
p_

# %%
1

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

# %%
X_train_counts.shape
# Out:
# (92466, 210963)

# %%
from  sklearn.neighbors  import KNeighborsClassifier
clf = KNeighborsClassifier().fit(X_train_counts, y_train)

# %%
X_test_counts = count_vect.transform(X_test)

# %%
print(X_test_counts.shape)
predicted = clf.predict(X_test_counts)
# Out:
# (10275, 210963)

# %%
from sklearn.metrics import *
acc = accuracy_score(predicted, y_test)
micro_f1 = f1_score(predicted, y_test, average = 'micro')
micro_p = precision_score(predicted, y_test, average = 'micro')
micro_r = recall_score(predicted, y_test, average = 'micro')
macro_f1 = f1_score(predicted, y_test, average = 'macro')
macro_p = precision_score(predicted, y_test, average = 'macro')
macro_r = recall_score(predicted, y_test, average = 'macro')
print('acc={0:1.4f}'.format(acc))
print('micro F1={0:1.4f}, micro P={1:1.4f}, micro R={2:1.4f}'.format(micro_f1, micro_p, micro_r))
print('macro F1={0:1.4f}, macro P={1:1.4f}, macro R={2:1.4f}\n'.format(macro_f1, macro_p, macro_r))
# Out:
# acc=0.0143
# micro F1=0.0143, micro P=0.0143, micro R=0.0143
# macro F1=0.0044, macro P=0.0078, macro R=0.0040
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_counts, y_train)
predicted = clf.predict(X_test_counts)

# %%
acc = accuracy_score(predicted, y_test)
micro_f1 = f1_score(predicted, y_test, average = 'micro')
micro_p = precision_score(predicted, y_test, average = 'micro')
micro_r = recall_score(predicted, y_test, average = 'micro')
macro_f1 = f1_score(predicted, y_test, average = 'macro')
macro_p = precision_score(predicted, y_test, average = 'macro')
macro_r = recall_score(predicted, y_test, average = 'macro')
print('acc={0:1.4f}'.format(acc))
print('micro F1={0:1.4f}, micro P={1:1.4f}, micro R={2:1.4f}'.format(micro_f1, micro_p, micro_r))
print('macro F1={0:1.4f}, macro P={1:1.4f}, macro R={2:1.4f}\n'.format(macro_f1, macro_p, macro_r))
# Out:
# acc=0.0747
# micro F1=0.0747, micro P=0.0747, micro R=0.0747
# macro F1=0.0066, macro P=0.0113, macro R=0.0069
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(
).fit(X_train_counts, y_train)
predicted = clf.predict(X_test_counts)

# %%
from sklearn.metrics import *
acc = accuracy_score(predicted, y_test)
micro_f1 = f1_score(predicted, y_test, average = 'micro')
micro_p = precision_score(predicted, y_test, average = 'micro')
micro_r = recall_score(predicted, y_test, average = 'micro')
macro_f1 = f1_score(predicted, y_test, average = 'macro')
macro_p = precision_score(predicted, y_test, average = 'macro')
macro_r = recall_score(predicted, y_test, average = 'macro')
print('acc={0:1.4f}'.format(acc))
print('micro F1={0:1.4f}, micro P={1:1.4f}, micro R={2:1.4f}'.format(micro_f1, micro_p, micro_r))
print('macro F1={0:1.4f}, macro P={1:1.4f}, macro R={2:1.4f}\n'.format(macro_f1, macro_p, macro_r))

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

scores = log_reg.predict_proba(X_test_new)[:,1]
fpr, tpr, thresholds_ROC = roc_curve(y_test, scores)
plt.plot(fpr, tpr, label='ROC curve ')
plt.plot([0, 1], [0, 1])
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.grid()
plt.show()
print('AUC-ROC = ',roc_auc_score(y_test,scores))

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

scores = log_reg.predict_proba(X_test_new)[:,1]
pre, rec, thresholds_PR = precision_recall_curve(y_test, scores)
plt.plot(rec, pre, label='Precision-Recall curve')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Precision-Recall curve')
plt.grid()
plt.show()
print('PR-AUC = ',average_precision_score(y_test, scores))
